# %%
import langchain
import pandas as pd
import os

# %%
from langchain_core.documents import Document

# %%
### understanding document structure in langchain

# %%
doc=Document(
    page_content="this is main ontent",
    metadata={
        "source":"example.txt",
        "author":"Subinay Nag",
        "page":1,
        "date":"14-02-2026"
    }
)
print("document structure")
print(f"page content: {doc.page_content}")
print(f"metadata: {doc.metadata}")
print(type(doc))

## why metadata matters
print("\nFilter search results")
print("Tracking data source")
print("providing context in response")
print("debugging and auditing")
# Out:
# document structure
# page content: this is main ontent
# metadata: {'source': 'example.txt', 'author': 'Subinay Nag', 'page': 1, 'date': '14-02-2026'}
# <class 'langchain_core.documents.base.Document'>
#
# Filter search results
# Tracking data source
# providing context in response
# debugging and auditing

# %%
### text file (.txt) the simplest case

# %%
## create a simple text files
import os
os.makedirs("data/text_files",exist_ok=True)

# %%
sample_text={
    "data/text_files/python_intro.txt":"""
Python is a high-level, interpreted programming language known for its simple syntax and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Widely used in web development, data analysis, artificial intelligence, and automation, Python has a large community and extensive libraries that make development faster and more efficient.
""",
"data/text_files/machine_learning.txt":"""
Machine learning is a branch of Artificial Intelligence that enables computers to learn from data without explicit programming. It uses algorithms to identify patterns, make predictions, and improve over time. Applications include image recognition, recommendation systems, fraud detection, and natural language processing across various industries.
"""
}
print(sample_text.items())

for filepath,content in sample_text.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)
print("file created!!!")
# Out:
# dict_items([('data/text_files/python_intro.txt', '\nPython is a high-level, interpreted programming language known for its simple syntax and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Widely used in web development, data analysis, artificial intelligence, and automation, Python has a large community and extensive libraries that make development faster and more efficient.\n'), ('data/text_files/machine_learning.txt', '\nMachine learning is a branch of Artificial Intelligence that enables computers to learn from data without explicit programming. It uses algorithms to identify patterns, make predictions, and improve over time. Applications include image recognition, recommendation systems, fraud detection, and natural language processing across various industries.\n')])
# file created!!!

# %%
## Text loader - read single file

# %%
from langchain_community.document_loaders import TextLoader

## loading a single file
loader=TextLoader("data/text_files/python_intro.txt",encoding="utf-8")
documents=loader.load()
print(documents)
print(f"Loaded {len(documents)} document")
print(f"content preview: {documents[0].page_content[:40]}")
print(f"metadata: {documents[0].metadata}")
# Out:
# [Document(metadata={'source': 'data/text_files/python_intro.txt'}, page_content='\nPython is a high-level, interpreted programming language known for its simple syntax and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Widely used in web development, data analysis, artificial intelligence, and automation, Python has a large community and extensive libraries that make development faster and more efficient.\n')]
# Loaded 1 document
# content preview:
# Python is a high-level, interpreted pro
# metadata: {'source': 'data/text_files/python_intro.txt'}

# %%
## Text loader - read multiple files

# %%
from langchain_community.document_loaders import DirectoryLoader

## loading multiple text files
dir_loader=DirectoryLoader(
    "data/text_files",
    glob="**/*", ## pattern to search file in the directory
    loader_cls= TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=True
)

documents=dir_loader.load()
print(f"Loaded {len(documents)} documents")
for i,doc in enumerate(documents):
    print(f"\nDocument {i+1}:")
    print(f"Source: {doc.metadata['source']}")
    print(f"Content: {doc.page_content}")
    print(f"Length: {len(doc.page_content)} characters")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 337.69it/s]
# Loaded 2 documents
#
# Document 1:
# Source: data\text_files\machine_learning.txt
# Content:
# Machine learning is a branch of Artificial Intelligence that enables computers to learn from data without explicit programming. It uses algorithms to identify patterns, make predictions, and improve over time. Applications include image recognition, recommendation systems, fraud detection, and natural language processing across various industries.
#
# Length: 351 characters
#
# Document 2:
# Source: data\text_files\python_intro.txt
# Content:
# Python is a high-level, interpreted programming language known for its simple syntax and readability. It supports multiple programming paradigms, including procedural, object-oriented, and functional programming. Widely used in web development, data analysis, artificial intelligence, and automation, Python has a large community and extensive libraries that make development faster and more efficient.
#
# ...
